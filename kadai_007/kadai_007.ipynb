# %%
#課題_007
#リスト
array = [
    "月曜日は晴れ",
    "火曜日は晴れ",
    "水曜日は晴れ",
    "木曜日は晴れ",
    "金曜日は晴れ",
    "土曜日は晴れ",
    "日曜日は晴れ"
]

#ディクショナリ
dictionary = {
    "mon": "月",
    "tue": "火",
    "wed": "水",
    "thu": "木",
    "fri": "金",
    "sat": "土",
    "sun": "日"
}

#結果
print(array[1])

print(dictionary["mon"])
# Out:
# 火曜日は晴れ
# 月
