# %%
#kadai_008
#1～15まで整数
var = 109

if var % 15 == 0:    #3と5の公倍数
    print("FizzBuzz")
elif var % 3 == 0:   #3の倍数
    print("Fizz")
elif var % 5 == 0:   #5の倍図
    print("Buzz")
else:              #それ以外の整数
    print(var)
# Out:
# 109
